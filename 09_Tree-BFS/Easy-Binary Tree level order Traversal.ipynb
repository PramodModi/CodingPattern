# %% [markdown]
# ## Problem: Binary Tree level order Traversal
# LeetCode: 102. Binary Tree Level Order Traversal
#
# https://leetcode.com/problems/binary-tree-level-order-traversal/description
#
#
# Given the root of a binary tree, return the level order traversal of its nodes' values. (i.e., from left to right, level by level).
#
#
#
# Example 1:
#
# ![image.png](attachment:image.png)
#
#     Input: root = [3,9,20,null,null,15,7]
#     Output: [[3],[9,20],[15,7]]
#
# Example 2:
#
#     Input: root = [1]
#     Output: [[1]]
#
# Example 3:
#
#     Input: root = []
#     Output: []
#
#
# Constraints:
#
#     The number of nodes in the tree is in the range [0, 2000].
#     -1000 <= Node.val <= 1000

# %% [markdown]
# ### Approach:
#
# Since this problem is asking to print values at each level. We use "BFS Pattern". For more details: https://github.com/PramodModi/CodingPattern/blob/main/09_Tree-BFS/01-Concept%20of%20BFS%20(Level%20Order%20Traversal).ipynb
#
# Will use queue to track of each level.
#
# Steps:
# 1. Start with root. Enqueue root in the queue
# 2. Run the loop till queue is empty
# 3. Run anothe rloop till the queue size. Here queue size is nothing but number of node in a particulr level.
# 4. Dequeue the node from queue, store the value in a temprary list.
# 5. Enqueue the left child node and right child node, if they are available.
# 6. Append result with temp data
# 7. Return the result.

# %%
## Creating Binary tree for testing purpose

from collections import deque

class Node:
    def __init__(self, val, left, right):
        self.val = val
        self.left = left
        self.right = right


def levelOrderTraverse(root):
    if root is None:
        return []
    q = deque([root])
    result = []
    while q:
        temp = []
        for _ in range(len(q)):
            node = q.popleft()
            temp.append(node.val)
            if node.left: q.append(node.left)
            if node.right: q.append(node.right)
        result.append(temp[:])
    return result

# %%
root = Node(3, Node(9, None, None), Node(20, (Node(15, None, None)), Node(7, None, None)))
levelOrderTraverse(root)
# Out:
# [[3], [9, 20], [15, 7]]
